# %% [markdown]
# <a href="https://colab.research.google.com/github/Gis-kost/geocod/blob/main/giga_chat_test_geocod_nominatium%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Установим необходимые пакеты
#!pip install geopy

from geopy.geocoders import Nominatim
import pandas as pd
from tqdm.notebook import tqdm_notebook # Для отображения прогресса выполнения
tqdm_notebook.pandas() # Чтобы прогрессии показывались внутри DataFrame операций

def geocode_address(address):
    """Получаем координаты адреса"""
    try:
        location = geolocator.geocode(address)
        if location is None:
            return {"latitude": None, "longitude": None}
        else:
            return {"latitude": location.latitude, "longitude": location.longitude}
    except Exception as e:
        print(f"Ошибка обработки адреса {address}: {e}")
        return {"latitude": None, "longitude": None}

# Создаем объект гео-кодера
geolocator = Nominatim(user_agent="geo-coding")

# Пример списка адресов
addresses = [
    'Москва, Красная площадь',
    'Санкт-Петербург, Невский проспект',
    'Новосибирск, Красный проспект'
]

# Преобразуем список адресов в DataFrame
df_addresses = pd.DataFrame(addresses, columns=['Address'])

# Применяем функцию геокодирования ко всему столбцу адресов
result_df = df_addresses.progress_apply(lambda row: pd.Series({**row.to_dict(), **geocode_address(row['Address'])}), axis=1)

print(result_df)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#                              Address   latitude  longitude
# 0            Москва, Красная площадь  55.753591  37.621501
# 1  Санкт-Петербург, Невский проспект  59.933976  30.328402
# 2      Новосибирск, Красный проспект  55.093057  82.916728

# %%
# Установка необходимых пакетов
#!pip install geopy folium

from geopy.geocoders import Nominatim
import pandas as pd
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()
import folium

def geocode_address(address):
    """Получение координат адреса."""
    try:
        location = geolocator.geocode(address)
        if location is None:
            return {"latitude": None, "longitude": None}
        else:
            return {"latitude": location.latitude, "longitude": location.longitude}
    except Exception as e:
        print(f"Ошибка обработки адреса {address}: {e}")
        return {"latitude": None, "longitude": None}

# Объект гео-кодера
geolocator = Nominatim(user_agent="geo-coding")

# Список адресов
addresses = [
    'Москва, Красная площадь',
    'Санкт-Петербург, Невский проспект',
    'Новосибирск, Красный проспект'
]

# Преобразование списка адресов в DataFrame
df_addresses = pd.DataFrame(addresses, columns=['Address'])

# Применение функции геокодирования ко всему столбцу адресов
result_df = df_addresses.progress_apply(
    lambda row: pd.Series({**row.to_dict(), **geocode_address(row['Address'])}),
    axis=1
)

# Создание карты
m = folium.Map(location=[result_df["latitude"].mean(), result_df["longitude"].mean()],
               zoom_start=5,
               tiles='OpenStreetMap')

# Добавление маркеров на карту
for index, row in result_df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['Address']).add_to(m)

# Отображение карты
display(m)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
pip install --upgrade jupyter nbformat nbconvert
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.16.0
#     Uninstalling jupyter-server-1.16.0:
#       Successfully uninstalled jupyter-server-1.16.0
# ...
