# %% [markdown]
# <a href="https://colab.research.google.com/github/Gis-kost/geocod/blob/main/giga_chat_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Установим необходимые пакеты
#!pip install geopy

from geopy.geocoders import Nominatim
import pandas as pd
from tqdm.notebook import tqdm_notebook # Для отображения прогресса выполнения
tqdm_notebook.pandas() # Чтобы прогрессии показывались внутри DataFrame операций

def geocode_address(address):
    """Получаем координаты адреса"""
    try:
        location = geolocator.geocode(address)
        if location is None:
            return {"latitude": None, "longitude": None}
        else:
            return {"latitude": location.latitude, "longitude": location.longitude}
    except Exception as e:
        print(f"Ошибка обработки адреса {address}: {e}")
        return {"latitude": None, "longitude": None}

# Создаем объект гео-кодера
geolocator = Nominatim(user_agent="geo-coding")

# Пример списка адресов
addresses = [
    'Москва, Красная площадь',
    'Санкт-Петербург, Невский проспект',
    'Новосибирск, Красный проспект'
]

# Преобразуем список адресов в DataFrame
df_addresses = pd.DataFrame(addresses, columns=['Address'])

# Применяем функцию геокодирования ко всему столбцу адресов
result_df = df_addresses.progress_apply(lambda row: pd.Series({**row.to_dict(), **geocode_address(row['Address'])}), axis=1)

print(result_df)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#                              Address   latitude  longitude
# 0            Москва, Красная площадь  55.753591  37.621501
# 1  Санкт-Петербург, Невский проспект  59.933976  30.328402
# 2      Новосибирск, Красный проспект  55.093057  82.916728

# %%
# Установка необходимых пакетов
#!pip install geopy folium

from geopy.geocoders import Nominatim
import pandas as pd
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()
import folium

def geocode_address(address):
    """Получение координат адреса."""
    try:
        location = geolocator.geocode(address)
        if location is None:
            return {"latitude": None, "longitude": None}
        else:
            return {"latitude": location.latitude, "longitude": location.longitude}
    except Exception as e:
        print(f"Ошибка обработки адреса {address}: {e}")
        return {"latitude": None, "longitude": None}

# Объект гео-кодера
geolocator = Nominatim(user_agent="geo-coding")

# Список адресов
addresses = [
    'Москва, Красная площадь',
    'Санкт-Петербург, Невский проспект',
    'Новосибирск, Красный проспект'
]

# Преобразование списка адресов в DataFrame
df_addresses = pd.DataFrame(addresses, columns=['Address'])

# Применение функции геокодирования ко всему столбцу адресов
result_df = df_addresses.progress_apply(
    lambda row: pd.Series({**row.to_dict(), **geocode_address(row['Address'])}),
    axis=1
)

# Создание карты
m = folium.Map(location=[result_df["latitude"].mean(), result_df["longitude"].mean()],
               zoom_start=5,
               tiles='OpenStreetMap')

# Добавление маркеров на карту
for index, row in result_df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['Address']).add_to(m)

# Отображение карты
display(m)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9a6d1771c46c2002ef02dc2e520a5eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9a6d1771c46c2002ef02dc2e520a5eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9a6d1771c46c2002ef02dc2e520a5eb = L.map(
#                 &quot;map_a9a6d1771c46c2002ef02dc2e520a5eb&quot;,
#                 {
#                     center: [56.926874533333326, 50.28887726666667],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e1de88c693eb71dca16e5e73bbc2a43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e1de88c693eb71dca16e5e73bbc2a43.addTo(map_a9a6d1771c46c2002ef02dc2e520a5eb);
#
#
#             var marker_c0dc456503dfeaedbe4f105611bc2cd2 = L.marker(
#                 [55.7535908, 37.6215014],
#                 {
# }
#             ).addTo(map_a9a6d1771c46c2002ef02dc2e520a5eb);
#
#
#         var popup_2a7960477e4bf8ffa5e70381bc743680 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73ea41cf9952eceacd64e0d47373f69e = $(`&lt;div id=&quot;html_73ea41cf9952eceacd64e0d47373f69e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Москва, Красная площадь&lt;/div&gt;`)[0];
#                 popup_2a7960477e4bf8ffa5e70381bc743680.setContent(html_73ea41cf9952eceacd64e0d47373f69e);
#
#
#
#         marker_c0dc456503dfeaedbe4f105611bc2cd2.bindPopup(popup_2a7960477e4bf8ffa5e70381bc743680)
#         ;
#
#
#
#
#             var marker_8a8e2d78e6cb39794d337486cceed349 = L.marker(
#                 [59.9339756, 30.3284024],
#                 {
# }
#             ).addTo(map_a9a6d1771c46c2002ef02dc2e520a5eb);
#
#
#         var popup_25c8490f44e6c47b9f6c797b0dceacc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26959417d9fd62f1ba0a5bd31f2d001b = $(`&lt;div id=&quot;html_26959417d9fd62f1ba0a5bd31f2d001b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Санкт-Петербург, Невский проспект&lt;/div&gt;`)[0];
#                 popup_25c8490f44e6c47b9f6c797b0dceacc6.setContent(html_26959417d9fd62f1ba0a5bd31f2d001b);
#
#
#
#         marker_8a8e2d78e6cb39794d337486cceed349.bindPopup(popup_25c8490f44e6c47b9f6c797b0dceacc6)
#         ;
#
#
#
#
#             var marker_1b5706d6130f96061bdaad2689281a3c = L.marker(
#                 [55.0930572, 82.916728],
#                 {
# }
#             ).addTo(map_a9a6d1771c46c2002ef02dc2e520a5eb);
#
#
#         var popup_2630184ac50aac4087af15ace9c5a010 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff5c7bf7630c5e35c6324963f037b740 = $(`&lt;div id=&quot;html_ff5c7bf7630c5e35c6324963f037b740&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Новосибирск, Красный проспект&lt;/div&gt;`)[0];
#                 popup_2630184ac50aac4087af15ace9c5a010.setContent(html_ff5c7bf7630c5e35c6324963f037b740);
#
#
#
#         marker_1b5706d6130f96061bdaad2689281a3c.bindPopup(popup_2630184ac50aac4087af15ace9c5a010)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
