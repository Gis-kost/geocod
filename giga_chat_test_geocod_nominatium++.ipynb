# %% [markdown]
# <a href="https://colab.research.google.com/github/Gis-kost/geocod/blob/main/giga_chat_test_geocod_nominatium%2B%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Установка необходимых пакетов
# !pip install geopy folium

from geopy.geocoders import Nominatim
import pandas as pd
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()
import folium

def geocode_address(address):
    """Получение координат адреса."""
    try:
        location = geolocator.geocode(address)
        if location is None:
            return {"latitude": None, "longitude": None}
        else:
            return {"latitude": location.latitude, "longitude": location.longitude}
    except Exception as e:
        print(f"Ошибка обработки адреса {address}: {e}")
        return {"latitude": None, "longitude": None}

# Объект гео-кодера
geolocator = Nominatim(user_agent="geo-coding")

# Список адресов
addresses = [
    'Москва, Красная площадь',
    'Санкт-Петербург, Невский проспект',
    'Новосибирск, Красный проспект'
]

# Преобразование списка адресов в DataFrame
df_addresses = pd.DataFrame(addresses, columns=['Address'])

# Применение функции геокодирования ко всему столбцу адресов
result_df = df_addresses.progress_apply(
    lambda row: pd.Series({**row.to_dict(), **geocode_address(row['Address'])}),
    axis=1
)

# Создание карты
m = folium.Map(location=[result_df["latitude"].mean(), result_df["longitude"].mean()],
               zoom_start=5,
               tiles='OpenStreetMap')

# Добавление маркеров на карту
for index, row in result_df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['Address']).add_to(m)

# Отображение карты
display(m)
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.5)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.1.31)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=%D0%A1%D0%B0%D0%BD%D0%BA%D1%82-%D0%9F%D0%B5%D1%82%D0%B5%D1%80%D0%B1%D1%83%D1%80%D0%B3%2C+%D0%9D%D0%B5%D0%B2%D1%81%D0%BA%D0%B8%D0%B9+%D0%BF%D1%80%D0%BE%D1%81%D0%BF%D0%B5%D0%BA%D1%82&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=%D0%9D%D0%BE%D0%B2%D0%BE%D1%81%D0%B8%D0%B1%D0%B8%D1%80%D1%81%D0%BA%2C+%D0%9A%D1%80%D0%B0%D1%81%D0%BD%D1%8B%D0%B9+%D0%BF%D1%80%D0%BE%D1%81%D0%BF%D0%B5%D0%BA%D1%82&format=json&limit=1
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40f26aaeed3333c51dcb6d915983277a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40f26aaeed3333c51dcb6d915983277a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40f26aaeed3333c51dcb6d915983277a = L.map(
#                 &quot;map_40f26aaeed3333c51dcb6d915983277a&quot;,
#                 {
#                     center: [56.926874533333326, 50.28887726666667],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a12e2bdb019caaf447b6bbc71a9de3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a12e2bdb019caaf447b6bbc71a9de3e.addTo(map_40f26aaeed3333c51dcb6d915983277a);
#
#
#             var marker_e8946a8b5ccca2486e57ec6e79564461 = L.marker(
#                 [55.7535908, 37.6215014],
#                 {
# }
#             ).addTo(map_40f26aaeed3333c51dcb6d915983277a);
#
#
#         var popup_302af0d8c0c00a0b65d435ddf917ab68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f927f6f9bfee13e8d3e09a13b681d05 = $(`&lt;div id=&quot;html_9f927f6f9bfee13e8d3e09a13b681d05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Москва, Красная площадь&lt;/div&gt;`)[0];
#                 popup_302af0d8c0c00a0b65d435ddf917ab68.setContent(html_9f927f6f9bfee13e8d3e09a13b681d05);
#
#
#
#         marker_e8946a8b5ccca2486e57ec6e79564461.bindPopup(popup_302af0d8c0c00a0b65d435ddf917ab68)
#         ;
#
#
#
#
#             var marker_b31da74b50d4483fe46173d70b18f898 = L.marker(
#                 [59.9339756, 30.3284024],
#                 {
# }
#             ).addTo(map_40f26aaeed3333c51dcb6d915983277a);
#
#
#         var popup_d457736f634019024d36bd416d185ae4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feab72e5a663e551f1ede20d33e8fcd2 = $(`&lt;div id=&quot;html_feab72e5a663e551f1ede20d33e8fcd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Санкт-Петербург, Невский проспект&lt;/div&gt;`)[0];
#                 popup_d457736f634019024d36bd416d185ae4.setContent(html_feab72e5a663e551f1ede20d33e8fcd2);
#
#
#
#         marker_b31da74b50d4483fe46173d70b18f898.bindPopup(popup_d457736f634019024d36bd416d185ae4)
#         ;
#
#
#
#
#             var marker_afd602340d8550f00283f8275b771b71 = L.marker(
#                 [55.0930572, 82.916728],
#                 {
# }
#             ).addTo(map_40f26aaeed3333c51dcb6d915983277a);
#
#
#         var popup_91bee819e0b5d2122d9b77cc07eac857 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b6efa3de463443913f9a40918849cd4 = $(`&lt;div id=&quot;html_8b6efa3de463443913f9a40918849cd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Новосибирск, Красный проспект&lt;/div&gt;`)[0];
#                 popup_91bee819e0b5d2122d9b77cc07eac857.setContent(html_8b6efa3de463443913f9a40918849cd4);
#
#
#
#         marker_afd602340d8550f00283f8275b771b71.bindPopup(popup_91bee819e0b5d2122d9b77cc07eac857)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
